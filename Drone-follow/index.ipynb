# %%
import os
import string
from pytube import YouTube


def checkFileName(file):
    validChars = "-_.() %s%s" % (string.ascii_letters, string.digits)
    return ''.join(c if c in validChars else '_' for c in file)

# video URLs
urls = [
    "https://www.youtube.com/watch?v=2NFwY15tRtA&t=2s",
    "https://www.youtube.com/watch?v=5dRramZVu2Q",
    "https://www.youtube.com/watch?v=WeF4wpw7w9k"
]


def downloadVideo(video_urls):
    for url in urls:
        try:
            yt = YouTube(url)
            stream = yt.streams.get_highest_resolution()
            if stream:
                print(f"Downloading {yt.title}...")
                stream.download()
                print(f"{yt.title} downloaded successfully.")
            else:
                print(f"No stream found for {yt.title}.")
        except Exception as e:
            print(f"Error downloading {url}: {e}")


downloadVideo(urls)
# Out:
# Downloading Cyclist and vehicle tracking - 2...
# Cyclist and vehicle tracking - 2 downloaded successfully.
# Downloading Drone Tracking Video...
# Drone Tracking Video downloaded successfully.
# Downloading Cyclist and vehicle Tracking - 1...
# Cyclist and vehicle Tracking - 1 downloaded successfully.

# %%
import os
import numpy as np
import cv2

def process_video(video_file, output_folder):
    
    os.makedirs(output_folder, exist_ok=True)
    
    cap = cv2.VideoCapture(video_file)
    if not cap.isOpened():
        print(f"Error: Could not open video file: {video_file}")
        return
    
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if frame_count == 0:
        print(f"Error: Video file {video_file} has no frames.")
        cap.release()
        return
    
    frames_processed = 0
    
    while frames_processed < frame_count:
        ret, frame = cap.read()
        if not ret:
            break
        
        #  the 7th frame
        if frames_processed % 7 != 0:
            frames_processed += 1
            continue
        
      
        frame_filename = f"frame_{frames_processed}.jpg"
        frame_path = os.path.join(output_folder, frame_filename)
        cv2.imwrite(frame_path, frame)
        
        frames_processed += 1
    
    cap.release()

def process_videos(filenames):
    for filename in filenames:
        print(f"Processing video: {filename}")
        video_name = os.path.splitext(os.path.basename(filename))[0]
        output_folder = f'{video_name}_frames'
        process_video(filename, output_folder)

filenames = [
    'Cyclist and vehicle Tracking - 1.mp4',
    'Cyclist and vehicle Tracking - 2.mp4',
    'Drone Tracking Video.mp4'
]

filenames = [filename.replace("’", "") for filename in filenames]
process_videos(filenames)
# Out:
# Processing video: Cyclist and vehicle Tracking - 1.mp4
# Processing video: Cyclist and vehicle Tracking - 2.mp4
# Processing video: Drone Tracking Video.mp4

# %%
import os
import numpy as np
import cv2

def process_video(video_file, output_folder):

    os.makedirs(output_folder, exist_ok=True)
    
    cap = cv2.VideoCapture(video_file)
    if not cap.isOpened():
        print(f"Error: Could not open video file: {video_file}")
        return
    
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if frame_count == 0:
        print(f"Error: Video file {video_file} has no frames.")
        cap.release()
        return
    
    frames_processed = 0
    all_frames = []
    
    while frames_processed < frame_count:
        ret, frame = cap.read()
        if not ret:
            break
        
        
        if frames_processed % 7 != 0:
            frames_processed += 1
            continue
        
        
        frame = cv2.resize(frame, (1080, 1920))  
        
    
        
        all_frames.append(frame)
        
        frames_processed += 1
    
    cap.release()
    
    
    frames_array = np.array(all_frames)
    np.save(os.path.join(output_folder, 'frames.npy'), frames_array)

def process_videos(filenames):
    for filename in filenames:
        print(f"Processing video: {filename}")
        video_name = os.path.splitext(os.path.basename(filename))[0]
        output_folder = f'{video_name}_frames'
        process_video(filename, output_folder)

filenames = [
    'Cyclist and vehicle Tracking - 1.mp4',
    'Cyclist and vehicle Tracking - 2.mp4',
    'Drone Tracking Video.mp4'
]

filenames = [filename.replace("’", "") for filename in filenames]
process_videos(filenames)
# Out:
# Processing video: Cyclist and vehicle Tracking - 1.mp4
# Processing video: Cyclist and vehicle Tracking - 2.mp4
# Processing video: Drone Tracking Video.mp4

# %%
import numpy as np
import os
import cv2

# Process image
def processImage(imgPath, res=(1080, 1920)):
    try:
        # Load the image
        img = cv2.imread(imgPath)

        # Resize the image to the given resolution
        resized = cv2.resize(img, res[::-1])

        return resized
    except Exception as e:
        print(f"Error processing image {imgPath}: {e}")
        return None

# List of folder paths containing image files
folderPaths = [
    'Cyclist and vehicle Tracking - 1_frames',
    'Cyclist and vehicle Tracking - 2_frames',
    'Drone Tracking Video_frames'
]


resolution = (1080, 1920)

# Iterate over each folder
for i, folder_path in enumerate(folderPaths, start=1):
    # List to store resized images
    resizedImages = []

    # Iterate over each file in the folder
    for filename in os.listdir(folder_path):
        image_path = os.path.join(folder_path, filename)

       
        resizedImage = processImage(image_path, resolution)
        if resizedImage is not None:
            resizedImages.append(resizedImage)

    # Convert resized images to a npy array
    resizedImgArray = np.array(resizedImages, dtype=np.uint8)

   
    framesFile = f'frames{i}.npy'
    np.save(framesFile, resizedImgArray)

    
    print(f"folder {i} processed and saved successfully.")
# Out:
# All images in folder 1 processed and saved to frames1.npy successfully.
# All images in folder 2 processed and saved to frames2.npy successfully.
# All images in folder 3 processed and saved to frames3.npy successfully.

# %%
import numpy as np
import os
import cv2
import torch

# use yolov5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5x')  # Adjust the model variant as needed

# only detect car or bicycle objects
classes_of_interest = ['car', 'bicycle']

# function to perform object detection on every colored frame
def detect_objects(frame):
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = model(frame_rgb)
    detections = results.pandas().xyxy[0]  # Use pandas format for easier manipulation
    return detections

# process the video and output the detections to a folder
def process_video(frames_array, output_folder):
    os.makedirs(output_folder, exist_ok=True) 
    
    for frameNum, frame in enumerate(frames_array):
        detections = detect_objects(frame)
        car_bike_detections = detections[detections['name'].isin(classes_of_interest)]
        
        # show the frame with the corresponding bounding boxes (if found)
        for index, detection in car_bike_detections.iterrows():
            bbox = [int(detection['xmin']), int(detection['ymin']), int(detection['xmax']), int(detection['ymax'])]
            class_name = detection['name']
            cv2.rectangle(frame, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (0, 255, 0), 2)
            cv2.putText(frame, f'{class_name}', (bbox[0], bbox[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        
        output_path = os.path.join(output_folder, f'frame{frameNum}.jpg')
        cv2.imwrite(output_path, frame)
        print(f"Saved frame {frameNum} with detections to {output_path}")

# process each video
frames_files = ["frames1.npy", "frames2.npy", "frames3.npy"]
output_folders = ["video1", "video2", "video3"]
for frames_file, output_folder in zip(frames_files, output_folders):
    frames_array = np.load(frames_file)
    process_video(frames_array, output_folder)

# close OpenCV windows
cv2.destroyAllWindows()
# Out:
# Using cache found in C:\Users\abdul/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-3-2 Python-3.10.5 torch-2.2.1+cpu CPU
#
# Fusing layers...
# YOLOv5x summary: 444 layers, 86705005 parameters, 0 gradients, 205.5 GFLOPs
# Adding AutoShape...
# Saved frame 0 with detections to video1\frame0.jpg
# Saved frame 1 with detections to video1\frame1.jpg
# Saved frame 2 with detections to video1\frame2.jpg
# Saved frame 3 with detections to video1\frame3.jpg
# Saved frame 4 with detections to video1\frame4.jpg
# Saved frame 5 with detections to video1\frame5.jpg
# Saved frame 6 with detections to video1\frame6.jpg
# Saved frame 7 with detections to video1\frame7.jpg
# Saved frame 8 with detections to video1\frame8.jpg
# Saved frame 9 with detections to video1\frame9.jpg
# Saved frame 10 with detections to video1\frame10.jpg
# Saved frame 11 with detections to video1\frame11.jpg
# Saved frame 12 with detections to video1\frame12.jpg
# Saved frame 13 with detections to video1\frame13.jpg
# Saved frame 14 with detections to video1\frame14.jpg
# Saved frame 15 with detections to video1\frame15.jpg
# Saved frame 16 with detections to video1\frame16.jpg
# Saved frame 17 with detections to video1\frame17.jpg
# Saved frame 18 with detections to video1\frame18.jpg
# Saved frame 19 with detections to video1\frame19.jpg
# Saved frame 20 with detections to video1\frame20.jpg
# Saved frame 21 with detections to video1\frame21.jpg
# Saved frame 22 with detections to video1\frame22.jpg
# Saved frame 23 with detections to video1\frame23.jpg
# Saved frame 24 with detections to video1\frame24.jpg
# Saved frame 25 with detections to video1\frame25.jpg
# Saved frame 26 with detections to video1\frame26.jpg
# Saved frame 27 with detections to video1\frame27.jpg
# Saved frame 28 with detections to video1\frame28.jpg
# Saved frame 29 with detections to video1\frame29.jpg
# Saved frame 30 with detections to video1\frame30.jpg
# Saved frame 31 with detections to video1\frame31.jpg
# Saved frame 32 with detections to video1\frame32.jpg
# Saved frame 33 with detections to video1\frame33.jpg
# Saved frame 34 with detections to video1\frame34.jpg
# Saved frame 35 with detections to video1\frame35.jpg
# Saved frame 36 with detections to video1\frame36.jpg
# Saved frame 37 with detections to video1\frame37.jpg
# Saved frame 38 with detections to video1\frame38.jpg
# Saved frame 39 with detections to video1\frame39.jpg
# Saved frame 40 with detections to video1\frame40.jpg
# Saved frame 41 with detections to video1\frame41.jpg
# Saved frame 42 with detections to video1\frame42.jpg
# Saved frame 43 with detections to video1\frame43.jpg
# Saved frame 44 with detections to video1\frame44.jpg
# Saved frame 45 with detections to video1\frame45.jpg
# Saved frame 46 with detections to video1\frame46.jpg
# Saved frame 47 with detections to video1\frame47.jpg
# Saved frame 48 with detections to video1\frame48.jpg
# Saved frame 49 with detections to video1\frame49.jpg
# Saved frame 50 with detections to video1\frame50.jpg
# Saved frame 51 with detections to video1\frame51.jpg
# Saved frame 52 with detections to video1\frame52.jpg
# Saved frame 53 with detections to video1\frame53.jpg
# Saved frame 54 with detections to video1\frame54.jpg
# Saved frame 55 with detections to video1\frame55.jpg
# Saved frame 56 with detections to video1\frame56.jpg
# Saved frame 57 with detections to video1\frame57.jpg
# Saved frame 58 with detections to video1\frame58.jpg
# Saved frame 59 with detections to video1\frame59.jpg
# Saved frame 60 with detections to video1\frame60.jpg
# Saved frame 61 with detections to video1\frame61.jpg
# Saved frame 62 with detections to video1\frame62.jpg
# Saved frame 63 with detections to video1\frame63.jpg
# Saved frame 64 with detections to video1\frame64.jpg
# Saved frame 65 with detections to video1\frame65.jpg
# Saved frame 66 with detections to video1\frame66.jpg
# Saved frame 67 with detections to video1\frame67.jpg
# Saved frame 68 with detections to video1\frame68.jpg
# Saved frame 69 with detections to video1\frame69.jpg
# Saved frame 70 with detections to video1\frame70.jpg
# Saved frame 71 with detections to video1\frame71.jpg
# Saved frame 72 with detections to video1\frame72.jpg
# Saved frame 73 with detections to video1\frame73.jpg
# Saved frame 74 with detections to video1\frame74.jpg
# Saved frame 75 with detections to video1\frame75.jpg
# Saved frame 76 with detections to video1\frame76.jpg
# Saved frame 77 with detections to video1\frame77.jpg
# Saved frame 78 with detections to video1\frame78.jpg
# Saved frame 79 with detections to video1\frame79.jpg
# Saved frame 80 with detections to video1\frame80.jpg
# Saved frame 81 with detections to video1\frame81.jpg
# Saved frame 82 with detections to video1\frame82.jpg
# Saved frame 83 with detections to video1\frame83.jpg
# Saved frame 84 with detections to video1\frame84.jpg
# Saved frame 85 with detections to video1\frame85.jpg
# Saved frame 86 with detections to video1\frame86.jpg
# Saved frame 87 with detections to video1\frame87.jpg
# Saved frame 88 with detections to video1\frame88.jpg
# Saved frame 89 with detections to video1\frame89.jpg
# Saved frame 90 with detections to video1\frame90.jpg
# Saved frame 91 with detections to video1\frame91.jpg
# Saved frame 92 with detections to video1\frame92.jpg
# Saved frame 93 with detections to video1\frame93.jpg
# Saved frame 94 with detections to video1\frame94.jpg
# Saved frame 95 with detections to video1\frame95.jpg
# Saved frame 96 with detections to video1\frame96.jpg
# Saved frame 97 with detections to video1\frame97.jpg
# Saved frame 98 with detections to video1\frame98.jpg
# Saved frame 99 with detections to video1\frame99.jpg
# Saved frame 100 with detections to video1\frame100.jpg
# Saved frame 101 with detections to video1\frame101.jpg
# Saved frame 102 with detections to video1\frame102.jpg
# Saved frame 103 with detections to video1\frame103.jpg
# Saved frame 104 with detections to video1\frame104.jpg
# Saved frame 105 with detections to video1\frame105.jpg
# Saved frame 106 with detections to video1\frame106.jpg
# Saved frame 107 with detections to video1\frame107.jpg
# Saved frame 108 with detections to video1\frame108.jpg
# Saved frame 109 with detections to video1\frame109.jpg
# Saved frame 110 with detections to video1\frame110.jpg
# Saved frame 111 with detections to video1\frame111.jpg
# Saved frame 112 with detections to video1\frame112.jpg
# Saved frame 113 with detections to video1\frame113.jpg
# Saved frame 114 with detections to video1\frame114.jpg
# Saved frame 115 with detections to video1\frame115.jpg
# Saved frame 116 with detections to video1\frame116.jpg
# Saved frame 117 with detections to video1\frame117.jpg
# Saved frame 118 with detections to video1\frame118.jpg
# Saved frame 119 with detections to video1\frame119.jpg
# Saved frame 120 with detections to video1\frame120.jpg
# Saved frame 121 with detections to video1\frame121.jpg
# Saved frame 122 with detections to video1\frame122.jpg
# Saved frame 123 with detections to video1\frame123.jpg
# Saved frame 124 with detections to video1\frame124.jpg
# Saved frame 125 with detections to video1\frame125.jpg
# Saved frame 126 with detections to video1\frame126.jpg
# Saved frame 127 with detections to video1\frame127.jpg
# Saved frame 128 with detections to video1\frame128.jpg
# Saved frame 129 with detections to video1\frame129.jpg
# Saved frame 130 with detections to video1\frame130.jpg
# Saved frame 131 with detections to video1\frame131.jpg
# Saved frame 132 with detections to video1\frame132.jpg
# Saved frame 133 with detections to video1\frame133.jpg
# Saved frame 134 with detections to video1\frame134.jpg
# Saved frame 135 with detections to video1\frame135.jpg
# Saved frame 136 with detections to video1\frame136.jpg
# Saved frame 137 with detections to video1\frame137.jpg
# Saved frame 138 with detections to video1\frame138.jpg
# Saved frame 139 with detections to video1\frame139.jpg
# Saved frame 140 with detections to video1\frame140.jpg
# Saved frame 141 with detections to video1\frame141.jpg
# Saved frame 142 with detections to video1\frame142.jpg
# Saved frame 143 with detections to video1\frame143.jpg
# Saved frame 144 with detections to video1\frame144.jpg
# Saved frame 145 with detections to video1\frame145.jpg
# Saved frame 146 with detections to video1\frame146.jpg
# Saved frame 147 with detections to video1\frame147.jpg
# Saved frame 148 with detections to video1\frame148.jpg
# Saved frame 149 with detections to video1\frame149.jpg
# Saved frame 150 with detections to video1\frame150.jpg
# Saved frame 151 with detections to video1\frame151.jpg
# Saved frame 152 with detections to video1\frame152.jpg
# Saved frame 153 with detections to video1\frame153.jpg
# Saved frame 154 with detections to video1\frame154.jpg
# Saved frame 155 with detections to video1\frame155.jpg
# Saved frame 156 with detections to video1\frame156.jpg
# Saved frame 157 with detections to video1\frame157.jpg
# Saved frame 158 with detections to video1\frame158.jpg
# Saved frame 159 with detections to video1\frame159.jpg
# Saved frame 160 with detections to video1\frame160.jpg
# Saved frame 161 with detections to video1\frame161.jpg
# Saved frame 162 with detections to video1\frame162.jpg
# Saved frame 163 with detections to video1\frame163.jpg
# Saved frame 164 with detections to video1\frame164.jpg
# Saved frame 165 with detections to video1\frame165.jpg
# Saved frame 166 with detections to video1\frame166.jpg
# Saved frame 167 with detections to video1\frame167.jpg
# Saved frame 168 with detections to video1\frame168.jpg
# Saved frame 169 with detections to video1\frame169.jpg
# Saved frame 170 with detections to video1\frame170.jpg
# Saved frame 171 with detections to video1\frame171.jpg
# Saved frame 172 with detections to video1\frame172.jpg
# Saved frame 173 with detections to video1\frame173.jpg
# Saved frame 174 with detections to video1\frame174.jpg
# Saved frame 175 with detections to video1\frame175.jpg
# Saved frame 176 with detections to video1\frame176.jpg
# Saved frame 177 with detections to video1\frame177.jpg
# Saved frame 178 with detections to video1\frame178.jpg
# Saved frame 179 with detections to video1\frame179.jpg
# Saved frame 180 with detections to video1\frame180.jpg
# Saved frame 181 with detections to video1\frame181.jpg
# Saved frame 182 with detections to video1\frame182.jpg
# Saved frame 183 with detections to video1\frame183.jpg
# Saved frame 184 with detections to video1\frame184.jpg
# Saved frame 185 with detections to video1\frame185.jpg
# Saved frame 186 with detections to video1\frame186.jpg
# Saved frame 187 with detections to video1\frame187.jpg
# Saved frame 188 with detections to video1\frame188.jpg
# Saved frame 189 with detections to video1\frame189.jpg
# Saved frame 190 with detections to video1\frame190.jpg
# Saved frame 191 with detections to video1\frame191.jpg
# Saved frame 192 with detections to video1\frame192.jpg
# Saved frame 193 with detections to video1\frame193.jpg
# Saved frame 194 with detections to video1\frame194.jpg
# Saved frame 195 with detections to video1\frame195.jpg
# Saved frame 196 with detections to video1\frame196.jpg
# Saved frame 197 with detections to video1\frame197.jpg
# Saved frame 198 with detections to video1\frame198.jpg
# Saved frame 199 with detections to video1\frame199.jpg
# Saved frame 200 with detections to video1\frame200.jpg
# Saved frame 201 with detections to video1\frame201.jpg
# Saved frame 202 with detections to video1\frame202.jpg
# Saved frame 203 with detections to video1\frame203.jpg
# Saved frame 204 with detections to video1\frame204.jpg
# Saved frame 205 with detections to video1\frame205.jpg
# Saved frame 206 with detections to video1\frame206.jpg
# Saved frame 207 with detections to video1\frame207.jpg
# Saved frame 208 with detections to video1\frame208.jpg
# Saved frame 209 with detections to video1\frame209.jpg
# Saved frame 210 with detections to video1\frame210.jpg
# Saved frame 211 with detections to video1\frame211.jpg
# Saved frame 212 with detections to video1\frame212.jpg
# Saved frame 213 with detections to video1\frame213.jpg
# Saved frame 214 with detections to video1\frame214.jpg
# Saved frame 215 with detections to video1\frame215.jpg
# Saved frame 216 with detections to video1\frame216.jpg
# Saved frame 217 with detections to video1\frame217.jpg
# Saved frame 218 with detections to video1\frame218.jpg
# Saved frame 219 with detections to video1\frame219.jpg
# Saved frame 220 with detections to video1\frame220.jpg
# Saved frame 221 with detections to video1\frame221.jpg
# Saved frame 222 with detections to video1\frame222.jpg
# Saved frame 223 with detections to video1\frame223.jpg
# Saved frame 224 with detections to video1\frame224.jpg
# Saved frame 225 with detections to video1\frame225.jpg
# Saved frame 226 with detections to video1\frame226.jpg
# Saved frame 227 with detections to video1\frame227.jpg
# Saved frame 228 with detections to video1\frame228.jpg
# Saved frame 229 with detections to video1\frame229.jpg
# Saved frame 230 with detections to video1\frame230.jpg
# Saved frame 231 with detections to video1\frame231.jpg
# Saved frame 232 with detections to video1\frame232.jpg
# Saved frame 233 with detections to video1\frame233.jpg
# Saved frame 234 with detections to video1\frame234.jpg
# Saved frame 235 with detections to video1\frame235.jpg
# Saved frame 236 with detections to video1\frame236.jpg
# Saved frame 237 with detections to video1\frame237.jpg
# Saved frame 238 with detections to video1\frame238.jpg
# Saved frame 239 with detections to video1\frame239.jpg
# Saved frame 240 with detections to video1\frame240.jpg
# Saved frame 241 with detections to video1\frame241.jpg
# Saved frame 242 with detections to video1\frame242.jpg
# Saved frame 243 with detections to video1\frame243.jpg
# Saved frame 244 with detections to video1\frame244.jpg
# Saved frame 245 with detections to video1\frame245.jpg
# Saved frame 246 with detections to video1\frame246.jpg
# Saved frame 247 with detections to video1\frame247.jpg
# Saved frame 248 with detections to video1\frame248.jpg
# Saved frame 249 with detections to video1\frame249.jpg
# Saved frame 250 with detections to video1\frame250.jpg
# Saved frame 251 with detections to video1\frame251.jpg
# Saved frame 252 with detections to video1\frame252.jpg
# Saved frame 253 with detections to video1\frame253.jpg
# Saved frame 254 with detections to video1\frame254.jpg
# Saved frame 255 with detections to video1\frame255.jpg
# Saved frame 256 with detections to video1\frame256.jpg
# Saved frame 257 with detections to video1\frame257.jpg
# Saved frame 258 with detections to video1\frame258.jpg
# Saved frame 259 with detections to video1\frame259.jpg
# Saved frame 260 with detections to video1\frame260.jpg
# Saved frame 261 with detections to video1\frame261.jpg
# Saved frame 262 with detections to video1\frame262.jpg
# Saved frame 263 with detections to video1\frame263.jpg
# Saved frame 264 with detections to video1\frame264.jpg
# Saved frame 265 with detections to video1\frame265.jpg
# Saved frame 266 with detections to video1\frame266.jpg
# Saved frame 267 with detections to video1\frame267.jpg
# Saved frame 268 with detections to video1\frame268.jpg
# Saved frame 269 with detections to video1\frame269.jpg
# Saved frame 0 with detections to video2\frame0.jpg
# Saved frame 1 with detections to video2\frame1.jpg
# Saved frame 2 with detections to video2\frame2.jpg
# Saved frame 3 with detections to video2\frame3.jpg
# Saved frame 4 with detections to video2\frame4.jpg
# Saved frame 5 with detections to video2\frame5.jpg
# Saved frame 6 with detections to video2\frame6.jpg
# Saved frame 7 with detections to video2\frame7.jpg
# Saved frame 8 with detections to video2\frame8.jpg
# Saved frame 9 with detections to video2\frame9.jpg
# Saved frame 10 with detections to video2\frame10.jpg
# Saved frame 11 with detections to video2\frame11.jpg
# Saved frame 12 with detections to video2\frame12.jpg
# Saved frame 13 with detections to video2\frame13.jpg
# Saved frame 14 with detections to video2\frame14.jpg
# Saved frame 15 with detections to video2\frame15.jpg
# Saved frame 16 with detections to video2\frame16.jpg
# Saved frame 17 with detections to video2\frame17.jpg
# Saved frame 18 with detections to video2\frame18.jpg
# Saved frame 19 with detections to video2\frame19.jpg
# Saved frame 20 with detections to video2\frame20.jpg
# Saved frame 21 with detections to video2\frame21.jpg
# Saved frame 22 with detections to video2\frame22.jpg
# Saved frame 23 with detections to video2\frame23.jpg
# Saved frame 24 with detections to video2\frame24.jpg
# Saved frame 25 with detections to video2\frame25.jpg
# Saved frame 26 with detections to video2\frame26.jpg
# Saved frame 27 with detections to video2\frame27.jpg
# Saved frame 28 with detections to video2\frame28.jpg
# Saved frame 29 with detections to video2\frame29.jpg
# Saved frame 30 with detections to video2\frame30.jpg
# Saved frame 31 with detections to video2\frame31.jpg
# Saved frame 32 with detections to video2\frame32.jpg
# Saved frame 33 with detections to video2\frame33.jpg
# Saved frame 34 with detections to video2\frame34.jpg
# Saved frame 35 with detections to video2\frame35.jpg
# Saved frame 36 with detections to video2\frame36.jpg
# Saved frame 37 with detections to video2\frame37.jpg
# Saved frame 38 with detections to video2\frame38.jpg
# Saved frame 39 with detections to video2\frame39.jpg
# Saved frame 40 with detections to video2\frame40.jpg
# Saved frame 41 with detections to video2\frame41.jpg
# Saved frame 42 with detections to video2\frame42.jpg
# Saved frame 43 with detections to video2\frame43.jpg
# Saved frame 44 with detections to video2\frame44.jpg
# Saved frame 45 with detections to video2\frame45.jpg
# Saved frame 46 with detections to video2\frame46.jpg
# Saved frame 47 with detections to video2\frame47.jpg
# Saved frame 48 with detections to video2\frame48.jpg
# Saved frame 49 with detections to video2\frame49.jpg
# Saved frame 50 with detections to video2\frame50.jpg
# Saved frame 51 with detections to video2\frame51.jpg
# Saved frame 52 with detections to video2\frame52.jpg
# Saved frame 53 with detections to video2\frame53.jpg
# Saved frame 54 with detections to video2\frame54.jpg
# Saved frame 55 with detections to video2\frame55.jpg
# Saved frame 56 with detections to video2\frame56.jpg
# Saved frame 57 with detections to video2\frame57.jpg
# Saved frame 58 with detections to video2\frame58.jpg
# Saved frame 59 with detections to video2\frame59.jpg
# Saved frame 60 with detections to video2\frame60.jpg
# Saved frame 61 with detections to video2\frame61.jpg
# Saved frame 62 with detections to video2\frame62.jpg
# Saved frame 63 with detections to video2\frame63.jpg
# Saved frame 64 with detections to video2\frame64.jpg
# Saved frame 65 with detections to video2\frame65.jpg
# Saved frame 66 with detections to video2\frame66.jpg
# Saved frame 67 with detections to video2\frame67.jpg
# Saved frame 68 with detections to video2\frame68.jpg
# Saved frame 69 with detections to video2\frame69.jpg
# Saved frame 70 with detections to video2\frame70.jpg
# Saved frame 71 with detections to video2\frame71.jpg
# Saved frame 72 with detections to video2\frame72.jpg
# Saved frame 73 with detections to video2\frame73.jpg
# Saved frame 74 with detections to video2\frame74.jpg
# Saved frame 75 with detections to video2\frame75.jpg
# Saved frame 76 with detections to video2\frame76.jpg
# Saved frame 77 with detections to video2\frame77.jpg
# Saved frame 78 with detections to video2\frame78.jpg
# Saved frame 79 with detections to video2\frame79.jpg
# Saved frame 80 with detections to video2\frame80.jpg
# Saved frame 81 with detections to video2\frame81.jpg
# Saved frame 82 with detections to video2\frame82.jpg
# Saved frame 83 with detections to video2\frame83.jpg
# Saved frame 84 with detections to video2\frame84.jpg
# Saved frame 85 with detections to video2\frame85.jpg
# Saved frame 86 with detections to video2\frame86.jpg
# Saved frame 87 with detections to video2\frame87.jpg
# Saved frame 88 with detections to video2\frame88.jpg
# Saved frame 89 with detections to video2\frame89.jpg
# Saved frame 90 with detections to video2\frame90.jpg
# Saved frame 91 with detections to video2\frame91.jpg
# Saved frame 92 with detections to video2\frame92.jpg
# Saved frame 93 with detections to video2\frame93.jpg
# Saved frame 94 with detections to video2\frame94.jpg
# Saved frame 95 with detections to video2\frame95.jpg
# Saved frame 96 with detections to video2\frame96.jpg
# Saved frame 97 with detections to video2\frame97.jpg
# Saved frame 0 with detections to video3\frame0.jpg
# Saved frame 1 with detections to video3\frame1.jpg
# Saved frame 2 with detections to video3\frame2.jpg
# Saved frame 3 with detections to video3\frame3.jpg
# Saved frame 4 with detections to video3\frame4.jpg
# Saved frame 5 with detections to video3\frame5.jpg
# Saved frame 6 with detections to video3\frame6.jpg
# Saved frame 7 with detections to video3\frame7.jpg
# Saved frame 8 with detections to video3\frame8.jpg
# Saved frame 9 with detections to video3\frame9.jpg
# Saved frame 10 with detections to video3\frame10.jpg
# Saved frame 11 with detections to video3\frame11.jpg
# Saved frame 12 with detections to video3\frame12.jpg
# Saved frame 13 with detections to video3\frame13.jpg
# Saved frame 14 with detections to video3\frame14.jpg
# Saved frame 15 with detections to video3\frame15.jpg
# Saved frame 16 with detections to video3\frame16.jpg
# Saved frame 17 with detections to video3\frame17.jpg
# Saved frame 18 with detections to video3\frame18.jpg
# Saved frame 19 with detections to video3\frame19.jpg
# Saved frame 20 with detections to video3\frame20.jpg
# Saved frame 21 with detections to video3\frame21.jpg
# Saved frame 22 with detections to video3\frame22.jpg
# Saved frame 23 with detections to video3\frame23.jpg
# Saved frame 24 with detections to video3\frame24.jpg
# Saved frame 25 with detections to video3\frame25.jpg
# Saved frame 26 with detections to video3\frame26.jpg
# Saved frame 27 with detections to video3\frame27.jpg
# Saved frame 28 with detections to video3\frame28.jpg
# Saved frame 29 with detections to video3\frame29.jpg
# Saved frame 30 with detections to video3\frame30.jpg
# Saved frame 31 with detections to video3\frame31.jpg
# Saved frame 32 with detections to video3\frame32.jpg
# Saved frame 33 with detections to video3\frame33.jpg
# Saved frame 34 with detections to video3\frame34.jpg
# Saved frame 35 with detections to video3\frame35.jpg
# Saved frame 36 with detections to video3\frame36.jpg
# Saved frame 37 with detections to video3\frame37.jpg
# Saved frame 38 with detections to video3\frame38.jpg
# Saved frame 39 with detections to video3\frame39.jpg
# Saved frame 40 with detections to video3\frame40.jpg
# Saved frame 41 with detections to video3\frame41.jpg
# Saved frame 42 with detections to video3\frame42.jpg
# Saved frame 43 with detections to video3\frame43.jpg
# Saved frame 44 with detections to video3\frame44.jpg
# Saved frame 45 with detections to video3\frame45.jpg
# Saved frame 46 with detections to video3\frame46.jpg
# Saved frame 47 with detections to video3\frame47.jpg
# Saved frame 48 with detections to video3\frame48.jpg
# Saved frame 49 with detections to video3\frame49.jpg
# Saved frame 50 with detections to video3\frame50.jpg
# Saved frame 51 with detections to video3\frame51.jpg
# Saved frame 52 with detections to video3\frame52.jpg
# Saved frame 53 with detections to video3\frame53.jpg
# Saved frame 54 with detections to video3\frame54.jpg
# Saved frame 55 with detections to video3\frame55.jpg
# Saved frame 56 with detections to video3\frame56.jpg
# Saved frame 57 with detections to video3\frame57.jpg
# Saved frame 58 with detections to video3\frame58.jpg
# Saved frame 59 with detections to video3\frame59.jpg
# Saved frame 60 with detections to video3\frame60.jpg
# Saved frame 61 with detections to video3\frame61.jpg
# Saved frame 62 with detections to video3\frame62.jpg
# Saved frame 63 with detections to video3\frame63.jpg
# Saved frame 64 with detections to video3\frame64.jpg
# Saved frame 65 with detections to video3\frame65.jpg
# Saved frame 66 with detections to video3\frame66.jpg
# Saved frame 67 with detections to video3\frame67.jpg
# Saved frame 68 with detections to video3\frame68.jpg
# Saved frame 69 with detections to video3\frame69.jpg
# Saved frame 70 with detections to video3\frame70.jpg
# Saved frame 71 with detections to video3\frame71.jpg
# Saved frame 72 with detections to video3\frame72.jpg
# Saved frame 73 with detections to video3\frame73.jpg
# Saved frame 74 with detections to video3\frame74.jpg
# Saved frame 75 with detections to video3\frame75.jpg
# Saved frame 76 with detections to video3\frame76.jpg
# Saved frame 77 with detections to video3\frame77.jpg
# Saved frame 78 with detections to video3\frame78.jpg
# Saved frame 79 with detections to video3\frame79.jpg
# Saved frame 80 with detections to video3\frame80.jpg
# Saved frame 81 with detections to video3\frame81.jpg
# Saved frame 82 with detections to video3\frame82.jpg
# Saved frame 83 with detections to video3\frame83.jpg
# Saved frame 84 with detections to video3\frame84.jpg
# Saved frame 85 with detections to video3\frame85.jpg
# Saved frame 86 with detections to video3\frame86.jpg
# Saved frame 87 with detections to video3\frame87.jpg
# Saved frame 88 with detections to video3\frame88.jpg
# Saved frame 89 with detections to video3\frame89.jpg
# Saved frame 90 with detections to video3\frame90.jpg
# Saved frame 91 with detections to video3\frame91.jpg
# Saved frame 92 with detections to video3\frame92.jpg
# Saved frame 93 with detections to video3\frame93.jpg
# Saved frame 94 with detections to video3\frame94.jpg
# Saved frame 95 with detections to video3\frame95.jpg
# Saved frame 96 with detections to video3\frame96.jpg
# Saved frame 97 with detections to video3\frame97.jpg
# Saved frame 98 with detections to video3\frame98.jpg
# Saved frame 99 with detections to video3\frame99.jpg
# Saved frame 100 with detections to video3\frame100.jpg
# Saved frame 101 with detections to video3\frame101.jpg
# Saved frame 102 with detections to video3\frame102.jpg
# Saved frame 103 with detections to video3\frame103.jpg
# Saved frame 104 with detections to video3\frame104.jpg
# Saved frame 105 with detections to video3\frame105.jpg
# Saved frame 106 with detections to video3\frame106.jpg
# Saved frame 107 with detections to video3\frame107.jpg
# Saved frame 108 with detections to video3\frame108.jpg
# Saved frame 109 with detections to video3\frame109.jpg
# Saved frame 110 with detections to video3\frame110.jpg
# Saved frame 111 with detections to video3\frame111.jpg
# Saved frame 112 with detections to video3\frame112.jpg
# Saved frame 113 with detections to video3\frame113.jpg
# Saved frame 114 with detections to video3\frame114.jpg
# Saved frame 115 with detections to video3\frame115.jpg
# Saved frame 116 with detections to video3\frame116.jpg
# Saved frame 117 with detections to video3\frame117.jpg
# Saved frame 118 with detections to video3\frame118.jpg
# Saved frame 119 with detections to video3\frame119.jpg
# Saved frame 120 with detections to video3\frame120.jpg
# Saved frame 121 with detections to video3\frame121.jpg
# Saved frame 122 with detections to video3\frame122.jpg
# Saved frame 123 with detections to video3\frame123.jpg
# Saved frame 124 with detections to video3\frame124.jpg
# Saved frame 125 with detections to video3\frame125.jpg
# Saved frame 126 with detections to video3\frame126.jpg
# Saved frame 127 with detections to video3\frame127.jpg
# Saved frame 128 with detections to video3\frame128.jpg
# Saved frame 129 with detections to video3\frame129.jpg
# Saved frame 130 with detections to video3\frame130.jpg
# Saved frame 131 with detections to video3\frame131.jpg
# Saved frame 132 with detections to video3\frame132.jpg
# Saved frame 133 with detections to video3\frame133.jpg
# Saved frame 134 with detections to video3\frame134.jpg
# Saved frame 135 with detections to video3\frame135.jpg
# Saved frame 136 with detections to video3\frame136.jpg
# Saved frame 137 with detections to video3\frame137.jpg
# Saved frame 138 with detections to video3\frame138.jpg
# Saved frame 139 with detections to video3\frame139.jpg
# Saved frame 140 with detections to video3\frame140.jpg
# Saved frame 141 with detections to video3\frame141.jpg
# Saved frame 142 with detections to video3\frame142.jpg
# Saved frame 143 with detections to video3\frame143.jpg
# Saved frame 144 with detections to video3\frame144.jpg
# Saved frame 145 with detections to video3\frame145.jpg
# Saved frame 146 with detections to video3\frame146.jpg
# Saved frame 147 with detections to video3\frame147.jpg
# Saved frame 148 with detections to video3\frame148.jpg
# Saved frame 149 with detections to video3\frame149.jpg
# Saved frame 150 with detections to video3\frame150.jpg
# Saved frame 151 with detections to video3\frame151.jpg
# Saved frame 152 with detections to video3\frame152.jpg
# Saved frame 153 with detections to video3\frame153.jpg
# Saved frame 154 with detections to video3\frame154.jpg
# Saved frame 155 with detections to video3\frame155.jpg
# Saved frame 156 with detections to video3\frame156.jpg
# Saved frame 157 with detections to video3\frame157.jpg
# Saved frame 158 with detections to video3\frame158.jpg
# Saved frame 159 with detections to video3\frame159.jpg
# Saved frame 160 with detections to video3\frame160.jpg
# Saved frame 161 with detections to video3\frame161.jpg
# Saved frame 162 with detections to video3\frame162.jpg
# Saved frame 163 with detections to video3\frame163.jpg
# Saved frame 164 with detections to video3\frame164.jpg
# Saved frame 165 with detections to video3\frame165.jpg
# Saved frame 166 with detections to video3\frame166.jpg
# Saved frame 167 with detections to video3\frame167.jpg
# Saved frame 168 with detections to video3\frame168.jpg
# Saved frame 169 with detections to video3\frame169.jpg
# Saved frame 170 with detections to video3\frame170.jpg
# Saved frame 171 with detections to video3\frame171.jpg
# Saved frame 172 with detections to video3\frame172.jpg
# Saved frame 173 with detections to video3\frame173.jpg
# Saved frame 174 with detections to video3\frame174.jpg
# Saved frame 175 with detections to video3\frame175.jpg
# Saved frame 176 with detections to video3\frame176.jpg
# Saved frame 177 with detections to video3\frame177.jpg
# Saved frame 178 with detections to video3\frame178.jpg
# Saved frame 179 with detections to video3\frame179.jpg
# Saved frame 180 with detections to video3\frame180.jpg
# Saved frame 181 with detections to video3\frame181.jpg
# Saved frame 182 with detections to video3\frame182.jpg
# Saved frame 183 with detections to video3\frame183.jpg
# Saved frame 184 with detections to video3\frame184.jpg
# Saved frame 185 with detections to video3\frame185.jpg
# Saved frame 186 with detections to video3\frame186.jpg
# Saved frame 187 with detections to video3\frame187.jpg
# Saved frame 188 with detections to video3\frame188.jpg
# Saved frame 189 with detections to video3\frame189.jpg
# Saved frame 190 with detections to video3\frame190.jpg
# Saved frame 191 with detections to video3\frame191.jpg
# Saved frame 192 with detections to video3\frame192.jpg
# Saved frame 193 with detections to video3\frame193.jpg
# Saved frame 194 with detections to video3\frame194.jpg
# Saved frame 195 with detections to video3\frame195.jpg
# Saved frame 196 with detections to video3\frame196.jpg
# Saved frame 197 with detections to video3\frame197.jpg
# Saved frame 198 with detections to video3\frame198.jpg
# Saved frame 199 with detections to video3\frame199.jpg
# Saved frame 200 with detections to video3\frame200.jpg
# Saved frame 201 with detections to video3\frame201.jpg
# Saved frame 202 with detections to video3\frame202.jpg
# Saved frame 203 with detections to video3\frame203.jpg
# Saved frame 204 with detections to video3\frame204.jpg
# Saved frame 205 with detections to video3\frame205.jpg
# Saved frame 206 with detections to video3\frame206.jpg
# Saved frame 207 with detections to video3\frame207.jpg
# Saved frame 208 with detections to video3\frame208.jpg
# Saved frame 209 with detections to video3\frame209.jpg
# Saved frame 210 with detections to video3\frame210.jpg
# Saved frame 211 with detections to video3\frame211.jpg
# Saved frame 212 with detections to video3\frame212.jpg
# Saved frame 213 with detections to video3\frame213.jpg
# Saved frame 214 with detections to video3\frame214.jpg
# Saved frame 215 with detections to video3\frame215.jpg
# Saved frame 216 with detections to video3\frame216.jpg
# Saved frame 217 with detections to video3\frame217.jpg
# Saved frame 218 with detections to video3\frame218.jpg
# Saved frame 219 with detections to video3\frame219.jpg
# Saved frame 220 with detections to video3\frame220.jpg
# Saved frame 221 with detections to video3\frame221.jpg
# Saved frame 222 with detections to video3\frame222.jpg
# Saved frame 223 with detections to video3\frame223.jpg
# Saved frame 224 with detections to video3\frame224.jpg
# Saved frame 225 with detections to video3\frame225.jpg
# Saved frame 226 with detections to video3\frame226.jpg
# Saved frame 227 with detections to video3\frame227.jpg
# Saved frame 228 with detections to video3\frame228.jpg
# Saved frame 229 with detections to video3\frame229.jpg
# Saved frame 230 with detections to video3\frame230.jpg
# Saved frame 231 with detections to video3\frame231.jpg
# Saved frame 232 with detections to video3\frame232.jpg
# Saved frame 233 with detections to video3\frame233.jpg
# Saved frame 234 with detections to video3\frame234.jpg
# Saved frame 235 with detections to video3\frame235.jpg
# Saved frame 236 with detections to video3\frame236.jpg
# Saved frame 237 with detections to video3\frame237.jpg
# Saved frame 238 with detections to video3\frame238.jpg
# Saved frame 239 with detections to video3\frame239.jpg
# Saved frame 240 with detections to video3\frame240.jpg
# Saved frame 241 with detections to video3\frame241.jpg
# Saved frame 242 with detections to video3\frame242.jpg
# Saved frame 243 with detections to video3\frame243.jpg
# Saved frame 244 with detections to video3\frame244.jpg
# Saved frame 245 with detections to video3\frame245.jpg
# Saved frame 246 with detections to video3\frame246.jpg
# Saved frame 247 with detections to video3\frame247.jpg
# Saved frame 248 with detections to video3\frame248.jpg
# Saved frame 249 with detections to video3\frame249.jpg
# Saved frame 250 with detections to video3\frame250.jpg
# Saved frame 251 with detections to video3\frame251.jpg
# Saved frame 252 with detections to video3\frame252.jpg
# Saved frame 253 with detections to video3\frame253.jpg
# Saved frame 254 with detections to video3\frame254.jpg
# Saved frame 255 with detections to video3\frame255.jpg
# Saved frame 256 with detections to video3\frame256.jpg
# Saved frame 257 with detections to video3\frame257.jpg
# Saved frame 258 with detections to video3\frame258.jpg
# Saved frame 259 with detections to video3\frame259.jpg
# Saved frame 260 with detections to video3\frame260.jpg
# Saved frame 261 with detections to video3\frame261.jpg
# Saved frame 262 with detections to video3\frame262.jpg
# Saved frame 263 with detections to video3\frame263.jpg
# Saved frame 264 with detections to video3\frame264.jpg
# Saved frame 265 with detections to video3\frame265.jpg
# Saved frame 266 with detections to video3\frame266.jpg
# Saved frame 267 with detections to video3\frame267.jpg
# Saved frame 268 with detections to video3\frame268.jpg
# Saved frame 269 with detections to video3\frame269.jpg
# Saved frame 270 with detections to video3\frame270.jpg
# Saved frame 271 with detections to video3\frame271.jpg
# Saved frame 272 with detections to video3\frame272.jpg
# Saved frame 273 with detections to video3\frame273.jpg
# Saved frame 274 with detections to video3\frame274.jpg
# Saved frame 275 with detections to video3\frame275.jpg
# Saved frame 276 with detections to video3\frame276.jpg
# Saved frame 277 with detections to video3\frame277.jpg
# Saved frame 278 with detections to video3\frame278.jpg
# Saved frame 279 with detections to video3\frame279.jpg
# Saved frame 280 with detections to video3\frame280.jpg
# Saved frame 281 with detections to video3\frame281.jpg
# Saved frame 282 with detections to video3\frame282.jpg
# Saved frame 283 with detections to video3\frame283.jpg
# Saved frame 284 with detections to video3\frame284.jpg
# Saved frame 285 with detections to video3\frame285.jpg
# Saved frame 286 with detections to video3\frame286.jpg
# Saved frame 287 with detections to video3\frame287.jpg
# Saved frame 288 with detections to video3\frame288.jpg
# Saved frame 289 with detections to video3\frame289.jpg
# Saved frame 290 with detections to video3\frame290.jpg
# Saved frame 291 with detections to video3\frame291.jpg
# Saved frame 292 with detections to video3\frame292.jpg
# Saved frame 293 with detections to video3\frame293.jpg
# Saved frame 294 with detections to video3\frame294.jpg
# Saved frame 295 with detections to video3\frame295.jpg
# Saved frame 296 with detections to video3\frame296.jpg
# Saved frame 297 with detections to video3\frame297.jpg
# Saved frame 298 with detections to video3\frame298.jpg
# Saved frame 299 with detections to video3\frame299.jpg
# Saved frame 300 with detections to video3\frame300.jpg
# Saved frame 301 with detections to video3\frame301.jpg
# Saved frame 302 with detections to video3\frame302.jpg
# Saved frame 303 with detections to video3\frame303.jpg
# Saved frame 304 with detections to video3\frame304.jpg
# Saved frame 305 with detections to video3\frame305.jpg
# Saved frame 306 with detections to video3\frame306.jpg
# Saved frame 307 with detections to video3\frame307.jpg
# Saved frame 308 with detections to video3\frame308.jpg
# Saved frame 309 with detections to video3\frame309.jpg
# Saved frame 310 with detections to video3\frame310.jpg
# Saved frame 311 with detections to video3\frame311.jpg
# Saved frame 312 with detections to video3\frame312.jpg
# Saved frame 313 with detections to video3\frame313.jpg
# Saved frame 314 with detections to video3\frame314.jpg
# Saved frame 315 with detections to video3\frame315.jpg
# Saved frame 316 with detections to video3\frame316.jpg
# Saved frame 317 with detections to video3\frame317.jpg
# Saved frame 318 with detections to video3\frame318.jpg
# Saved frame 319 with detections to video3\frame319.jpg
# Saved frame 320 with detections to video3\frame320.jpg
# Saved frame 321 with detections to video3\frame321.jpg
# Saved frame 322 with detections to video3\frame322.jpg
# Saved frame 323 with detections to video3\frame323.jpg
# Saved frame 324 with detections to video3\frame324.jpg
# Saved frame 325 with detections to video3\frame325.jpg
# Saved frame 326 with detections to video3\frame326.jpg
# Saved frame 327 with detections to video3\frame327.jpg
# Saved frame 328 with detections to video3\frame328.jpg
# Saved frame 329 with detections to video3\frame329.jpg
# Saved frame 330 with detections to video3\frame330.jpg
# Saved frame 331 with detections to video3\frame331.jpg
# Saved frame 332 with detections to video3\frame332.jpg
# Saved frame 333 with detections to video3\frame333.jpg
# Saved frame 334 with detections to video3\frame334.jpg
# Saved frame 335 with detections to video3\frame335.jpg
# Saved frame 336 with detections to video3\frame336.jpg
# Saved frame 337 with detections to video3\frame337.jpg
# Saved frame 338 with detections to video3\frame338.jpg
# Saved frame 339 with detections to video3\frame339.jpg
# Saved frame 340 with detections to video3\frame340.jpg
# Saved frame 341 with detections to video3\frame341.jpg
# Saved frame 342 with detections to video3\frame342.jpg
# Saved frame 343 with detections to video3\frame343.jpg
# Saved frame 344 with detections to video3\frame344.jpg
# Saved frame 345 with detections to video3\frame345.jpg
# Saved frame 346 with detections to video3\frame346.jpg
# Saved frame 347 with detections to video3\frame347.jpg
# Saved frame 348 with detections to video3\frame348.jpg
# Saved frame 349 with detections to video3\frame349.jpg
# Saved frame 350 with detections to video3\frame350.jpg
# Saved frame 351 with detections to video3\frame351.jpg
# Saved frame 352 with detections to video3\frame352.jpg
# Saved frame 353 with detections to video3\frame353.jpg
# Saved frame 354 with detections to video3\frame354.jpg
# Saved frame 355 with detections to video3\frame355.jpg
# Saved frame 356 with detections to video3\frame356.jpg
# Saved frame 357 with detections to video3\frame357.jpg
# Saved frame 358 with detections to video3\frame358.jpg
# Saved frame 359 with detections to video3\frame359.jpg
# Saved frame 360 with detections to video3\frame360.jpg
# Saved frame 361 with detections to video3\frame361.jpg
# Saved frame 362 with detections to video3\frame362.jpg
# Saved frame 363 with detections to video3\frame363.jpg
# Saved frame 364 with detections to video3\frame364.jpg
# Saved frame 365 with detections to video3\frame365.jpg
# Saved frame 366 with detections to video3\frame366.jpg
# Saved frame 367 with detections to video3\frame367.jpg
# Saved frame 368 with detections to video3\frame368.jpg
# Saved frame 369 with detections to video3\frame369.jpg
# Saved frame 370 with detections to video3\frame370.jpg
# Saved frame 371 with detections to video3\frame371.jpg
# Saved frame 372 with detections to video3\frame372.jpg
# Saved frame 373 with detections to video3\frame373.jpg
# Saved frame 374 with detections to video3\frame374.jpg
# Saved frame 375 with detections to video3\frame375.jpg
# Saved frame 376 with detections to video3\frame376.jpg
# Saved frame 377 with detections to video3\frame377.jpg
# Saved frame 378 with detections to video3\frame378.jpg
# Saved frame 379 with detections to video3\frame379.jpg
# Saved frame 380 with detections to video3\frame380.jpg
# Saved frame 381 with detections to video3\frame381.jpg
# Saved frame 382 with detections to video3\frame382.jpg
# Saved frame 383 with detections to video3\frame383.jpg
# Saved frame 384 with detections to video3\frame384.jpg
# Saved frame 385 with detections to video3\frame385.jpg
# Saved frame 386 with detections to video3\frame386.jpg
# Saved frame 387 with detections to video3\frame387.jpg
# Saved frame 388 with detections to video3\frame388.jpg
# Saved frame 389 with detections to video3\frame389.jpg
# Saved frame 390 with detections to video3\frame390.jpg
# Saved frame 391 with detections to video3\frame391.jpg
# Saved frame 392 with detections to video3\frame392.jpg
# Saved frame 393 with detections to video3\frame393.jpg
# Saved frame 394 with detections to video3\frame394.jpg
# Saved frame 395 with detections to video3\frame395.jpg
# Saved frame 396 with detections to video3\frame396.jpg
# Saved frame 397 with detections to video3\frame397.jpg
# Saved frame 398 with detections to video3\frame398.jpg
# Saved frame 399 with detections to video3\frame399.jpg
# Saved frame 400 with detections to video3\frame400.jpg
# Saved frame 401 with detections to video3\frame401.jpg
# Saved frame 402 with detections to video3\frame402.jpg
# Saved frame 403 with detections to video3\frame403.jpg
# Saved frame 404 with detections to video3\frame404.jpg
# Saved frame 405 with detections to video3\frame405.jpg
# Saved frame 406 with detections to video3\frame406.jpg
# Saved frame 407 with detections to video3\frame407.jpg
# Saved frame 408 with detections to video3\frame408.jpg
# Saved frame 409 with detections to video3\frame409.jpg
# Saved frame 410 with detections to video3\frame410.jpg
# Saved frame 411 with detections to video3\frame411.jpg
# Saved frame 412 with detections to video3\frame412.jpg
# Saved frame 413 with detections to video3\frame413.jpg
# Saved frame 414 with detections to video3\frame414.jpg
# Saved frame 415 with detections to video3\frame415.jpg
# Saved frame 416 with detections to video3\frame416.jpg
# Saved frame 417 with detections to video3\frame417.jpg
# Saved frame 418 with detections to video3\frame418.jpg
# Saved frame 419 with detections to video3\frame419.jpg
# Saved frame 420 with detections to video3\frame420.jpg
# Saved frame 421 with detections to video3\frame421.jpg
# Saved frame 422 with detections to video3\frame422.jpg
# Saved frame 423 with detections to video3\frame423.jpg
# Saved frame 424 with detections to video3\frame424.jpg
# Saved frame 425 with detections to video3\frame425.jpg
# Saved frame 426 with detections to video3\frame426.jpg
# Saved frame 427 with detections to video3\frame427.jpg
# Saved frame 428 with detections to video3\frame428.jpg
# Saved frame 429 with detections to video3\frame429.jpg
# Saved frame 430 with detections to video3\frame430.jpg
# Saved frame 431 with detections to video3\frame431.jpg
# Saved frame 432 with detections to video3\frame432.jpg
# Saved frame 433 with detections to video3\frame433.jpg
# Saved frame 434 with detections to video3\frame434.jpg
# Saved frame 435 with detections to video3\frame435.jpg
# Saved frame 436 with detections to video3\frame436.jpg
# Saved frame 437 with detections to video3\frame437.jpg
# Saved frame 438 with detections to video3\frame438.jpg
# Saved frame 439 with detections to video3\frame439.jpg
# Saved frame 440 with detections to video3\frame440.jpg
# Saved frame 441 with detections to video3\frame441.jpg
# Saved frame 442 with detections to video3\frame442.jpg
# Saved frame 443 with detections to video3\frame443.jpg
# Saved frame 444 with detections to video3\frame444.jpg
# Saved frame 445 with detections to video3\frame445.jpg
# Saved frame 446 with detections to video3\frame446.jpg
# Saved frame 447 with detections to video3\frame447.jpg
# Saved frame 448 with detections to video3\frame448.jpg
# Saved frame 449 with detections to video3\frame449.jpg

# %%
import torch
import cv2
import numpy as np
from filterpy.kalman import KalmanFilter

# Load YOLOv5 model
yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5x')
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
yolo_model.to(device).eval()

# Define Kalman filter parameters
time_step = 1.0  # time step
kalman_filter = KalmanFilter(dim_x=4, dim_z=2)
kalman_filter.F = np.array([[1, time_step, 0,  0],
                             [0,  1, 0,  0],
                             [0,  0, 1, time_step],
                             [0,  0, 0,  1]])

kalman_filter.H = np.array([[1, 0, 0, 0],
                             [0, 0, 1, 0]])

kalman_filter.R *= 10  
kalman_filter.P *= 1000  
kalman_filter.Q *= 0.01  

objects_of_interest = ['car', 'bicycle']

# Array of video paths and output video names
video_paths = ['Cyclist and vehicle tracking - 2.mp4', 'Drone Tracking Video.mp4']
output_video_names = ['output_video2.mp4', 'output_video3.mp4']

for vid_path, output_vid_name in zip(video_paths, output_video_names):
    
    video_cap = cv2.VideoCapture(vid_path)
    
    # Get video properties
    vid_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    vid_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    vid_fps = int(video_cap.get(cv2.CAP_PROP_FPS))

    # Define codec and create VideoWriter object
    fourcc_codec = cv2.VideoWriter_fourcc(*'mp4v')
    vid_writer = cv2.VideoWriter(output_vid_name, fourcc_codec, vid_fps, (vid_width, vid_height))

    # Initialize variables for object tracking
    tracked_objects_dict = {}  # dictionary to store tracked object states
    obj_id_counter = 0  # counter for assigning object IDs
    frame_counter = 0  # counter for frames
    
    while video_cap.isOpened():
        ret, frame = video_cap.read()
        if not ret:
            break
        
        frame_counter += 1
        if frame_counter % 3 != 0:  # Skip frames that are not multiples of 3
            continue

        # Perform object detection using YOLOv5
        results = yolo_model(frame)
        detections = results.pandas().xyxy[0]  # Use pandas format for easier manipulation
        car_bike_detections = detections[detections['name'].isin(objects_of_interest)]
        
        # Update Kalman filter and track objects
        for index, detection in car_bike_detections.iterrows():
            bbox = [detection['xmin'], detection['ymin'], detection['xmax'], detection['ymax']]
            measurement = np.array([bbox[0] + (bbox[2] - bbox[0]) / 2, bbox[1] + (bbox[3] - bbox[1]) / 2])  
            
            measurement = measurement.reshape(2, 1)

            # Assign unique object ID
            obj_id_counter += 1
            obj_id = obj_id_counter

            if obj_id not in tracked_objects_dict:
                kalman_filter.x[:2] = measurement
                kalman_filter.x[2:] = 0
                tracked_objects_dict[obj_id] = kalman_filter

            tracked_objects_dict[obj_id].predict()
            tracked_objects_dict[obj_id].update(measurement)

            # Draw trajectory lines and object bounding boxes on the frame
            prediction = tracked_objects_dict[obj_id].x[:2].astype(int)
            center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers

            if 0 <= center[0] < vid_width and 0 <= center[1] < vid_height:
                radius = 4
                color = (255, 0, 0)  
                thickness = -1  
                cv2.circle(frame, center, radius, color, thickness)
                cv2.rectangle(frame, (int(bbox[0]), int(bbox[1])), (int(bbox[2]), int(bbox[3])), (0, 255, 0), 2)

        # Write the frame to output video
        vid_writer.write(frame)

    video_cap.release()
    vid_writer.release()
    cv2.destroyAllWindows()
# Out:
# Using cache found in C:\Users\abdul/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-3-2 Python-3.10.5 torch-2.2.1+cpu CPU
#
# Fusing layers...
# YOLOv5x summary: 444 layers, 86705005 parameters, 0 gradients, 205.5 GFLOPs
# Adding AutoShape...
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
# C:\Users\abdul\AppData\Local\Temp\ipykernel_21700\1997730352.py:87: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   center = (int(prediction[0]), int(prediction[1]))  # Ensure center coordinates are integers
